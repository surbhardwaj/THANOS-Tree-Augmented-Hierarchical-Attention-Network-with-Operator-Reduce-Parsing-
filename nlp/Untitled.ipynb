# %%
import pandas as pd
data = pd.read_pickle("data/kaggle/train.pkl")

# %%
len(data)
# Out:
# 49824

# %%
data.tail(64)
# Out:
#                                                     Tree  \
# 55798  [( well ( ( ( its february ) ( of ( ( 2004 and...
# 31699  [( `` ( ( ( does ( a ( firm persuasion ) ) ) (...
# 12316  [( ( with ( ( ( star trek ) : ) ( insurrection...
# 18400  [( when ( ( a movie ) ( ( ( attempts ( to ( ( ...
# 12323  [( ( ( ( reese witherspoon ) and ) ( mark ruff...
# 8128   [( ( this movie ) ( ( ( is not ) ( for ( the s...
# 54906  [( ( attack ( of ( the clones ) ) ) ( ( ( is p...
# 57685  [( ( before ( ( ( batman ( -lrb- ( christian b...
# 53107  [( ( ( ( ( ( male ( nurse gaylord ) ) ( `` ( (...
# 2281   [( ( ( a ( ( stunning ( , ( spectacular ( , ps...
# 46853  [( ah ( , ( here ( ( is ( a ( good ( family mo...
# 12327  [( ( when ( ( jurassic park ) ( was ( released...
# 66979  [( ( the ( incredible ( shrinking man ) ) ) ( ...
# 69014  [( ( ( how many ) movies ) ( ( ( can you ) ( h...
# 49702  [( ( ( the ( / ( ( ( * ( main stars ) ) ( : ( ...
# ...
